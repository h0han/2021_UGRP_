# %%
import os, re, glob
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# %%
groups_folder_path = './2. Jointed_Datasets/'
categories = ['1. Pedestrian', '2. Lier', '3. Sitter', '4. Taxier', '5. Blocker']
num_classes = len(categories)

# %%
image_w = 500
image_h = 500

X = []
Y = []
  
for idex, categorie in enumerate(categories):
    label = [0 for i in range(num_classes)]
    label[idex] = 1
    image_dir = groups_folder_path + categorie + '/'
  
    for top, dir, f in os.walk(image_dir):
        for filename in f:
            print(image_dir+filename)
            img = cv2.imread(image_dir+filename)
            img = cv2.resize(img, None, fx=image_w/img.shape[1], fy=image_h/img.shape[0])
            X.append(img/256)
            Y.append(label)
            
X = np.array(X)
Y = np.array(Y)
 
X_train, X_test, Y_train, Y_test = train_test_split(X,Y)
xy = (X_train, X_test, Y_train, Y_test)
 
np.save("./3. img_data/img_data.npy", xy)
# Out:
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0000.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0001.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0002.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0003.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0004.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0005.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0006.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0007.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0008.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0009.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0010.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0011.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0012.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0013.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0014.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0015.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0016.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0017.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0018.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0019.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0020.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0021.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0022.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0023.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0024.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0025.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0026.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0027.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0028.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0029.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0030.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0031.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0032.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0033.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0034.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0035.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0036.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0037.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0038.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0039.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0040.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0041.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0042.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0043.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0044.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0045.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0046.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0047.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0048.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0049.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0050.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0051.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0052.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0053.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0054.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0055.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0056.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0057.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0058.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0059.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0060.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0061.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0062.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0063.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0064.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0065.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0066.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0067.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0068.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0069.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0070.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0071.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0072.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0073.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0074.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0075.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0076.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0077.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0078.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0079.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0080.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0081.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0082.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0083.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0084.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0085.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0086.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0087.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0088.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0089.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0090.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0091.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0092.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0093.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0094.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0095.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0096.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0097.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0098.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0099.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0100.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0101.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0102.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0103.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0104.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0105.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0106.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0107.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0108.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0109.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0110.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0111.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0112.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0113.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0114.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0115.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0116.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0117.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0118.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0119.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0120.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0121.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0122.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0123.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0124.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0125.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0126.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0127.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0128.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0129.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0130.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0131.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0132.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0133.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0134.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0135.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0136.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0137.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0138.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0139.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0140.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0141.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0142.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0143.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0144.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0145.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0146.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0147.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0148.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0149.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0150.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0151.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0152.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0153.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0154.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0155.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0156.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0157.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0158.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0159.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0160.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0161.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0162.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0163.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0164.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0165.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0166.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0167.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0168.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0169.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0170.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0171.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0172.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0173.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0174.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0175.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0176.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0177.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0178.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0179.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0180.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0181.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0182.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0183.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0184.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0185.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0186.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0187.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0188.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0189.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0190.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0191.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0192.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0193.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0194.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0195.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0196.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0197.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0198.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0199.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0200.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0201.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0202.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0203.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0204.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0205.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0206.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0207.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0208.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0209.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0210.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0211.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0212.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0213.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0214.jpg
# ./2. Jointed_Datasets/1. Pedestrian/pedestrian_0215.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0000.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0001.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0002.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0003.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0004.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0005.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0006.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0007.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0008.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0009.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0010.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0011.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0012.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0013.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0014.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0015.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0016.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0017.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0018.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0019.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0020.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0021.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0022.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0023.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0024.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0025.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0026.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0027.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0028.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0029.jpg
# ./2. Jointed_Datasets/2. Lier/lier_0030.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0000.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0001.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0002.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0003.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0004.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0005.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0006.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0007.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0008.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0009.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0010.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0011.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0012.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0013.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0014.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0015.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0016.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0017.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0018.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0019.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0020.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0021.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0022.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0023.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0024.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0025.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0026.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0027.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0028.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0029.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0030.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0031.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0032.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0033.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0034.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0035.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0036.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0037.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0038.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0039.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0040.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0041.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0042.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0043.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0044.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0045.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0046.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0047.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0048.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0049.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0050.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0051.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0052.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0053.jpg
# ./2. Jointed_Datasets/3. Sitter/sitter_0054.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0000.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0001.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0002.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0003.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0004.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0005.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0006.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0007.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0008.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0009.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0010.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0011.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0012.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0013.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0014.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0015.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0016.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0017.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0018.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0019.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0020.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0021.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0022.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0023.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0024.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0025.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0026.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0027.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0028.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0029.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0030.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0031.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0032.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0033.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0034.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0035.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0036.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0037.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0038.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0039.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0040.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0041.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0042.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0043.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0044.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0045.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0046.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0047.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0048.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0049.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0050.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0051.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0052.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0053.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0054.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0055.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0056.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0057.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0058.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0059.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0060.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0061.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0062.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0063.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0064.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0065.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0066.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0067.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0068.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0069.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0070.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0071.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0072.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0073.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0074.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0075.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0076.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0077.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0078.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0079.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0080.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0081.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0082.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0083.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0084.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0085.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0086.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0087.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0088.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0089.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0090.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0091.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0092.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0093.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0094.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0095.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0096.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0097.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0098.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0099.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0100.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0101.jpg
# ./2. Jointed_Datasets/4. Taxier/taxier_0102.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0000.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0001.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0002.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0003.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0004.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0005.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0006.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0007.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0008.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0009.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0010.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0011.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0012.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0013.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0014.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0015.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0016.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0017.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0018.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0019.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0020.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0021.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0022.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0023.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0024.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0025.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0026.jpg
# ./2. Jointed_Datasets/5. Blocker/blocker_0027.jpg

# %%
## 먼저 기존의 np.load를 np_load_old에 저장해둠.
np_load_old = np.load

## 기존의 parameter을 바꿔줌
np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True, **k)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Activation, Dense
from tensorflow.keras.layers import Flatten, Convolution2D, MaxPooling2D
from tensorflow.keras.models import load_model
import cv2
 
X_train, X_test, Y_train, Y_test = np.load('./3. img_data/img_data.npy')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-88e8683569d7> in <module>()
#       5 import cv2
#       6
# ----> 7 X_train, X_test, Y_train, Y_test = np.load('./3. img_data/img_data.npy')
#
# ~\Anaconda3\envs\tensor2_gpu\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     438             else:
#     439                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 440                                          pickle_kwargs=pickle_kwargs)
#     441         else:
#     442             # Try a pickle
#
# ~\Anaconda3\envs\tensor2_gpu\lib\site-packages\numpy\lib\format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     725         # The array contained Python objects. We need to unpickle the data.
#     726         if not allow_pickle:
# --> 727             raise ValueError("Object arrays cannot be loaded when "
#     728                              "allow_pickle=False")
#     729         if pickle_kwargs is None:
#
# ValueError: Object arrays cannot be loaded when allow_pickle=False

# %%
X_train.shape[1:]
# Out:
# (500, 500, 3)

# %%
model = Sequential()
model = Sequential()
model.add(Convolution2D(16, 3, 3, activation='relu', input_shape=X_train.shape[1:]))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
  
model.add(Convolution2D(64, 3, 3, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
 
model.add(Convolution2D(64, 3, 3))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
  
model.add(Flatten())
model.add(Dense(256, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes,activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 166, 166, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 83, 83, 16)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 83, 83, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 27, 27, 64)        9280
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 113,733
# Trainable params: 113,733
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_acc', patience=5)
model.fit(X_train, Y_train, batch_size=32, nb_epoch=100)
# Out:
# WARNING:tensorflow:The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 324 samples
# Epoch 1/100
# 324/324 [==============================] - 14s 44ms/sample - loss: 0.4406 - accuracy: 0.8068
# Epoch 2/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.4334 - accuracy: 0.8012
# Epoch 3/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.4249 - accuracy: 0.8185
# Epoch 4/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.4138 - accuracy: 0.8216
# Epoch 5/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.4162 - accuracy: 0.8074
# Epoch 6/100
# 324/324 [==============================] - 3s 9ms/sample - loss: 0.4055 - accuracy: 0.8247
# Epoch 7/100
# 324/324 [==============================] - 3s 9ms/sample - loss: 0.3957 - accuracy: 0.8272
# Epoch 8/100
# 324/324 [==============================] - 3s 9ms/sample - loss: 0.3697 - accuracy: 0.8352
# Epoch 9/100
# 324/324 [==============================] - 3s 9ms/sample - loss: 0.3370 - accuracy: 0.8519
# Epoch 10/100
# 324/324 [==============================] - 3s 9ms/sample - loss: 0.2955 - accuracy: 0.8660
# Epoch 11/100
# 324/324 [==============================] - 3s 9ms/sample - loss: 0.2659 - accuracy: 0.8802
# Epoch 12/100
# 324/324 [==============================] - 3s 9ms/sample - loss: 0.2416 - accuracy: 0.8883
# Epoch 13/100
# 324/324 [==============================] - 3s 9ms/sample - loss: 0.2011 - accuracy: 0.9099
# Epoch 14/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.1872 - accuracy: 0.9210
# Epoch 15/100
# 324/324 [==============================] - 4s 11ms/sample - loss: 0.1683 - accuracy: 0.9241
# Epoch 16/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.1732 - accuracy: 0.9296
# Epoch 17/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.1248 - accuracy: 0.9457
# Epoch 18/100
# 324/324 [==============================] - 3s 9ms/sample - loss: 0.1340 - accuracy: 0.9426
# Epoch 19/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.1111 - accuracy: 0.9568
# Epoch 20/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.1006 - accuracy: 0.9605
# Epoch 21/100
# 324/324 [==============================] - 3s 9ms/sample - loss: 0.1065 - accuracy: 0.9599
# Epoch 22/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0765 - accuracy: 0.9710
# Epoch 23/100
# 324/324 [==============================] - 3s 11ms/sample - loss: 0.0700 - accuracy: 0.9722
# Epoch 24/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0737 - accuracy: 0.9716
# Epoch 25/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0848 - accuracy: 0.9667
# Epoch 26/100
# 324/324 [==============================] - 4s 11ms/sample - loss: 0.0781 - accuracy: 0.9654
# Epoch 27/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0682 - accuracy: 0.9704
# Epoch 28/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0724 - accuracy: 0.9704
# Epoch 29/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0557 - accuracy: 0.9790
# Epoch 30/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0478 - accuracy: 0.9809
# Epoch 31/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0412 - accuracy: 0.9852
# Epoch 32/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0368 - accuracy: 0.9858
# Epoch 33/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0459 - accuracy: 0.9815
# Epoch 34/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0363 - accuracy: 0.9877
# Epoch 35/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0288 - accuracy: 0.9901
# Epoch 36/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0209 - accuracy: 0.9926
# Epoch 37/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0218 - accuracy: 0.9901
# Epoch 38/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0256 - accuracy: 0.9932
# Epoch 39/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0191 - accuracy: 0.9951
# Epoch 40/100
# 324/324 [==============================] - 3s 11ms/sample - loss: 0.0194 - accuracy: 0.9907
# Epoch 41/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0180 - accuracy: 0.9914
# Epoch 42/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0201 - accuracy: 0.9901
# Epoch 43/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0174 - accuracy: 0.9951
# Epoch 44/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0151 - accuracy: 0.9957
# Epoch 45/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0132 - accuracy: 0.9963
# Epoch 46/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0230 - accuracy: 0.9901
# Epoch 47/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0188 - accuracy: 0.9901
# Epoch 48/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0186 - accuracy: 0.9920
# Epoch 49/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0272 - accuracy: 0.9920
# Epoch 50/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0136 - accuracy: 0.9963
# Epoch 51/100
# 324/324 [==============================] - 3s 9ms/sample - loss: 0.0193 - accuracy: 0.9932
# Epoch 52/100
# 324/324 [==============================] - 3s 11ms/sample - loss: 0.0171 - accuracy: 0.9914
# Epoch 53/100
# 324/324 [==============================] - 4s 12ms/sample - loss: 0.0160 - accuracy: 0.9938
# Epoch 54/100
# 324/324 [==============================] - 3s 11ms/sample - loss: 0.0140 - accuracy: 0.9944
# Epoch 55/100
# 324/324 [==============================] - 4s 11ms/sample - loss: 0.0153 - accuracy: 0.9926
# Epoch 56/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0127 - accuracy: 0.9944
# Epoch 57/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0086 - accuracy: 0.9975
# Epoch 58/100
# 324/324 [==============================] - 3s 11ms/sample - loss: 0.0110 - accuracy: 0.9975
# Epoch 59/100
# 324/324 [==============================] - 3s 11ms/sample - loss: 0.0080 - accuracy: 0.9975
# Epoch 60/100
# 324/324 [==============================] - 3s 11ms/sample - loss: 0.0076 - accuracy: 0.9981
# Epoch 61/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0068 - accuracy: 0.9963
# Epoch 62/100
# 324/324 [==============================] - 3s 11ms/sample - loss: 0.0110 - accuracy: 0.9963
# Epoch 63/100
# 324/324 [==============================] - 4s 11ms/sample - loss: 0.0128 - accuracy: 0.9951
# Epoch 64/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0061 - accuracy: 0.9975
# Epoch 65/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0062 - accuracy: 0.9988
# Epoch 66/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0032 - accuracy: 0.9994
# Epoch 67/100
# 324/324 [==============================] - 3s 11ms/sample - loss: 0.0080 - accuracy: 0.9963
# Epoch 68/100
# 324/324 [==============================] - 4s 11ms/sample - loss: 0.0035 - accuracy: 1.0000
# Epoch 69/100
# 324/324 [==============================] - 4s 11ms/sample - loss: 0.0034 - accuracy: 0.9988
# Epoch 70/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0036 - accuracy: 0.9994
# Epoch 71/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0036 - accuracy: 1.0000
# Epoch 72/100
# 324/324 [==============================] - 3s 9ms/sample - loss: 0.0023 - accuracy: 1.0000
# Epoch 73/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0050 - accuracy: 0.9975
# Epoch 74/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0090 - accuracy: 0.9944
# Epoch 75/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0040 - accuracy: 0.9988
# Epoch 76/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0047 - accuracy: 0.9988
# Epoch 77/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0041 - accuracy: 0.9988
# Epoch 78/100
# 324/324 [==============================] - 3s 9ms/sample - loss: 0.0103 - accuracy: 0.9975
# Epoch 79/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0084 - accuracy: 0.9988
# Epoch 80/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0111 - accuracy: 0.9944
# Epoch 81/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0141 - accuracy: 0.9951
# Epoch 82/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0071 - accuracy: 0.9969
# Epoch 83/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0031 - accuracy: 1.0000
# Epoch 84/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0044 - accuracy: 0.9981
# Epoch 85/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0035 - accuracy: 1.0000
# Epoch 86/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0048 - accuracy: 0.9975
# Epoch 87/100
# 324/324 [==============================] - 3s 11ms/sample - loss: 0.0044 - accuracy: 1.0000
# Epoch 88/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0053 - accuracy: 0.9975
# Epoch 89/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0023 - accuracy: 1.0000
# Epoch 90/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0035 - accuracy: 0.9988
# Epoch 91/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0110 - accuracy: 0.9975
# Epoch 92/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0036 - accuracy: 0.9988
# Epoch 93/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0041 - accuracy: 0.9975
# Epoch 94/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0075 - accuracy: 0.9975
# Epoch 95/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0030 - accuracy: 1.0000
# Epoch 96/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0112 - accuracy: 0.9963
# Epoch 97/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0026 - accuracy: 1.0000
# Epoch 98/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0056 - accuracy: 0.9988
# Epoch 99/100
# 324/324 [==============================] - 3s 10ms/sample - loss: 0.0038 - accuracy: 0.9988
# Epoch 100/100
# 324/324 [==============================] - 3s 9ms/sample - loss: 0.0077 - accuracy: 0.9963

# %%
model.save('Gesture_Detection_Model.h5')

# %%
def Dataization(img_path):
    image_w = 500
    image_h = 500
    img = cv2.imread(img_path)
    img = cv2.resize(img, None, fx=image_w/img.shape[1], fy=image_h/img.shape[0])
    return (img/256)

# %%
src = []
name = []
test = []
image_dir = "./"
for file in os.listdir(image_dir):
    if (file.find('.jpg') is not -1):      
        src.append(image_dir + file)
        name.append(file)
        test.append(Dataization(image_dir + file))
 
 
test = np.array(test)
model = load_model('Gesture_Detection_Model.h5')
predict = model.predict_classes(test)
 
for i in range(len(test)):
    print(name[i] + " : , Predict : "+ str(categories[predict[i]]))
# Out:
# blocker_test.jpg : , Predict : 1. Pedestrian
# taxier_test.jpg : , Predict : 1. Pedestrian
